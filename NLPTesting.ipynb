# %% [markdown]
# Import Step:

# %%
import pandas as pd
import numpy as np

#When loading datasets for nlp it is not necerssary to use dataframes as typical ML so far
data = open('datasets/nfr.csv').read()

# %% [markdown]
# spaCy example:

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
doc = nlp(data)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['PE', 'The system', 'the display', 'The application', 'the color', 'the schema', 'Department', 'Homeland Security', 'US', 'the data', 'a 10x10 projection screen', '90%', 'viewers', 'Event / Activity data', 'a viewing distance', 'The product', 'normal business hours', 'the user', 'access', 'the client PC', 'the system', 'the time', 'the first six months', 'operation', 'the data', 'a 10x10 projection screen', '90%', 'viewers', 'Events', 'Activities', 'current time', 'a viewing distance', 'The product', 'it', 'authorized users', 'The product', 'authorized and unauthorized users', 'all access attempts', 'The product', '90%', 'new users', 'the display', 'Events', 'Activities', '90 minutes', 'the product', ',,\nPE', 'The product', 'date', 'the display', 'The system', 'a MDI form', 'that', 'the viewing', 'the graph', 'the data table', 'The system', 'Events', 'a vertical table', 'time', 'The system', 'the Events', 'a graph', 'time', 'All business rules', 'the Disputes System', 'compliance', 'the guidelines', 'Regulation E', 'Regulation Z.', 'The Disputes application', 'a detailed history', 'every action', 'that', 'a user', 'a dispute case', 'This', 'a complete audit trail', 'questions', 'regard', 'a particular dispute case', 'All actions', 'that', 'an existing dispute case', 'the case history', 'The Disputes System', 'both internal and external users', 'The Disputes System', 'users', 'any dispute cases', 'that', 'their cardholder base', 'The Disputes System', 'direct data entry', 'a dispute case', 'a user interface', 'that', 'real time responses', 'the users', 'The Disputes System', 'different levels', 'access', 'regard', 'disputes case initiation', 'follow-up actions', 'The Disputes System', 'view access capability', 'authorized users', 'the application', 'The Disputes System', 'update access capability', 'authorized users', 'the application', 'The Disputes System', 'the users', 'disputable transactions', 'the age', 'the transaction', 'a user interface', 'a dispute', 'ticket retrieval request', 'chargeback notification', 'the selected transaction', 'The Disputes System', 'the user', 'the ability', 'a single dispute case', 'multiple transactions', 'that', 'a single merchant', 'The Disputes System', 'the user', 'the ability', 'a ticket retrieval request', 'part', 'ticket retrieval creation process', 'the system', 'the user', 'all the required information', 'the ticket retrieval request', 'The ticket retrieval request', 'a document', 'that', 'merchant', 'the validity', 'a transaction', 'The Disputes System', 'the user', 'three unique types', 'ticket retrieval requests', 'The three types', 'ticket retrieval requests', '1) Request', 'original receipt (2) Request', 'a copy', 'the receipt', '(3) Request', 'a portfolio', 'A portfolio', 'documentation', 'that', 'proof', 'a purchase', 'the documentation', 'that', 'a car rental agency', 'that', 'a sales receipt', 'The Disputes System', 'external users', 'original receipts', 'Requests', 'original receipts', 'internal users', 'The Disputes System', 'a confirmation', 'the user', 'the creation', 'ticket retrieval request', 'that', 'the following information', 'the dispute case number', 'the type', 'retrieval', 'portfolio', 'the date', 'the merchant response', 'The Disputes System', 'the user', 'a chargeback request', 'The system', 'the user', 'the required information', 'a chargeback request', 'The chargeback request results', 'a printed chargeback notification', 'that', 'merchant', 'their account', 'no proof', 'the disputed transaction', 'The Disputes System', 'a confirmation', 'the user', 'the creation', 'a chargeback request', 'The confirmation', 'the following information', 'the dispute case number', 'the type', 'chargeback', 'the date', 'the merchant response', 'The Disputes System', 'the creation', 'duplicate dispute requests', '100%', 'the time', 'The Disputes System', 'a list', 'possible reason codes', 'a given transaction', 'The list', 'possible reason codes', 'the type', 't ...
# Verbs: ['refresh', 'match', 'set', 'project', 'read', 'view', 'have', 'project', 'determine', 'occur', 'view', 'ensure', 'access', 'authorize', 'distinguish', 'start', 'use', 'respond', 'keep', 'have', 'allow', 'display', 'display', 'specify', 'maintain', 'take', 'ensure', 'arise', 'modify', 'exist', 'record', 'prevent', 'access', 'belong', 'facilitate', 'support', 'provide', 'follow', 'provide', 'authorize', 'provide', 'authorize', 'allow', 'select', 'base', 'initiate', 'select', 'provide', 'initiate', 'belong', 'provide', 'create', 'initiate', 'prompt', 'enter', 'require', 'create', 'send', 'inquire', 'allow', 'create', 'consist', 'provide', 'receive', 'prevent', 'request', 'restrict', 'provide', 'contain', 'follow', 'request', 'copy', 'allow', 'create', 'initiate', 'prompt', 'enter', 'require', 'initiate', 'print', 'send', 'indicate', 'charge', 'provide', 'dispute', 'provide', 'contain', 'follow', 'request', 'pende', 'prevent', 'provide', 'give', 'derive', 'base', 'belong', 'accord', 'define', 'provide', 'view', 'exist', 'provide', 'include', 'search', 'allow', 'limit', 'meet', 'enter', 'provide', 'differentiate', '-code', 'provide', 'view', 'occur', 'provide', 'follow', 'follow', 'follow', 'give', 'filter', 'record', 'create', 'modify', 'take', 'include', 'perform', 'maintain', 'initiate', 'occur', 'age', 'generate', 'initiate', 'notify', 'occur', 'format', 'accord', 'specify', 'close', 'purge', 'support', 'support', 'interface', 'provide', 'recycle', 'run', 'exist', 'adhere', 'comply', 'comply', 'appear', 'expect', 'run', 'use', 'find', 'use', 'increase', 'agree', 'use', 'feel', 'use', 'learn', 'learn', 'locate', 'use', 'find', 'recycle', 'take', 'return', 'take', 'return', 'return', 'return', 'save', 'occur', 'adhere', 'bring', 'schedule', 'achieve', 'fail', 'handle', 'perform', 'recycle', 'handle', 'operate', 'interface', 'fall', 'establish', 'support', 'use', 'handle', 'request', 'recycle', 'request', 'recycle', 'update', 'access', 'search', 'have', 'enter', 'enter', 'view', 'claim', 'prevent', 'include', 'comply', 'comply', 'relate', 'recycle', 'comply', 'regard', 'search', 'prefer', 'use', 'include', 'make', 'include', 'resolve', 'locate', 'enter', 'override', 'return', 'return', 'determine', 'search', 'use', 'search', 'use', 'search', 'supply', 'search', 'find', 'retain', 'recycle', 'return', 'recycle', 'return', 'apply', 'select', 'recycle', 'apply', 'return', 'review', 'request', 'recycle', 'provide', 'retrieve', 'generate', 'base', 'recycle', 'include', 'recycle', 'use', 'include', 'include', 'use', 'include', 'sum', 'display', 'select', 'view', 'prefer', 'display', 'display', 'be', 'define', 'enter', 'base', 'include', 'attempt', 'recycle', 'recycle', 'select', 'save', 'save', 'work', 'colocate', 'locate', 'function', 'instal', 'require', 'locate', 'reside', 'make', 'include', 'need', 'integrate', 'look', 'feel', 'incorporate', 'brand', 'have', 'make', 'want', 'use', 'survey', 'report', 'use', 'use', 'reserve', 'give', 'survey', 'report', 'confirm', 'allow', 'select', 'choose', 'allow', 'view', 'use', 'navigate', 'setup', 'use', 'allow', 'conform', 'avoid', 'interrupt', 'complete', 'complete', 'achieve', 'create', 'encounter', 'handle', 'increase', 'handle', 'process', 'increase', 'expect', 'operate', 'use', 'interface', 'transmit', 'display', 'test', 'test', 'interface', 'communicate', 'interface', 'send', 'package', 'license', 'add', 'log', 'design', 'use', 'code', 'integrate', 'integrate', 'change', 'offer', 'take', 'install', 'register', 'have', 'register', 'find', 'use', 'integrate', 'translate', 'emerge', 'take', 'configure', 'expect', 'integrate', 'operate', 'instal', 'ensure', 'approve', 'have', 'approve', 'perform', 'ensure', 'correspond', 'enter', 'contain', 'enter', 'prevent', 'remain', 'remain', 'crash', 'have', 'receive', 'emerge', 'receive', 'transmit', 'instal', 'accommodate', 'find', 'display', 'accord', 'find', 'format', 'develop', 'record', 'notify', 'have', 'send', 'assign', 'contact', 'create ...
# every 60 seconds TIME
# Department of Homeland Security ORG
# US GPE
# 10x10 CARDINAL
# 90% PERCENT
# 30 CARDINAL
# normal business hours TIME
# 99% PERCENT
# the first six months DATE
# US GPE
# 10x10 CARDINAL
# 90% PERCENT
# 100 CARDINAL
# US GPE
# 90% PERCENT
# 90 minutes TIME
# Regulation Z. PERSON
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# three CARDINAL
# three CARDINAL
# 2 CARDINAL
# F:The Disputes System PRODUCT
# F: The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# F: The Disputes System PRODUCT
# F:The Disputes System PRODUCT
# 100% PERCENT
# F: The Disputes System PRODUCT
# the Disputes System ORG
# F:The Disputes System PRODUCT
# F: The Disputes System PRODUCT
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# 4 CARDINAL
# F: PRODUCT
# F:The Disputes System PRODUCT
# F:The Dispute System PRODUCT
# F: The Disputes System PRODUCT
# the Print Letter Utility ORG
# over 6 months DATE
# 5.5 CARDINAL
# Mozilla Firefox 1.0 PRODUCT
# the Choice Parts System ORG
# Interface Guidelines PERSON
# PO ORG
# Windows NORP
# Linux PERSON
# US GPE
# Adjusters ORG
# 95% PERCENT
# Adjusters and Collision Estimators ORG
# US GPE
# Collision Estimators ORG
# 80% PERCENT
# 1 month DATE
# US GPE
# 85% PERCENT
# US GPE
# Adjusters ORG
# two days DATE
# US GPE
# 90% PERCENT
# 15 seconds TIME
# under 15 seconds TIME
# 8 seconds TIME
# 8 seconds TIME
# 10 seconds TIME
# 10 seconds TIME
# 5 seconds TIME
# 5 seconds TIME
# 98% PERCENT
# 98% PERCENT
# more than 2% PERCENT
# SC ORG
# 1500 CARDINAL
# 1500 CARDINAL
# SC ORG
# 50 000 CARDINAL
# SC ORG
# 10 000 CARDINAL
# 2 years DATE
# ChoiceParts ORG
# approximately 1:00 AM TIME
# One CARDINAL
# Sarbanes-Oxley ORG
# vehicle year DATE
# zipcode PERSON
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# 30 miles QUANTITY
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# 1-10 CARDINAL
# DBMS ORG
# DBMS ORG
# Java PERSON
# DBMS ORG
# DBMS ORG
# Apache PRODUCT
# JBoss NORP
# Oracle NORP
# HSQL GPE
# customerï¿½s PERSON
# US GPE
# 80% PERCENT
# the first 2 weeks DATE
# US GPE
# 90% PERCENT
# 5 minutes TIME
# US GPE
# 80% PERCENT
# US GPE
# US GPE
# US GPE
# a few minutes TIME
# less than 15 minutes TIME
# US GPE
# US GPE
# US GPE
# Americans NORP
# 90% PERCENT
# 5 seconds TIME
# 98% PERCENT
# 8 seconds TIME
# 99.99% PERCENT
# SC ORG
# up to 1 000 CARDINAL
# 2 000 CARDINAL
# Release 2 ORG
# early morning TIME
# late afternoon hours TIME
# SC ORG
# 10 000 QUANTITY
# two years DATE
# 20 000 CARDINAL
# Release 2. ORG
# SC ORG
# at least 5 years DATE
# HTML ORG
# 80% PERCENT
# 8 CARDINAL
# 100% PERCENT
# one CARDINAL
# two-five CARDINAL
# five-or-more DATE
# US GPE
# 10 minutes TIME
# 90% PERCENT
# 10 minutes TIME
# MN ORG
# Design Patterns ORG
# 90% PERCENT
# 2 working days DATE
# MN ORG
# 80% PERCENT
# productï¿½s PERSON
# 5 minutes TIME
# 80% PERCENT
# US GPE
# productï¿½s PERSON
# 70% PERCENT
# 5 minutes TIME
# MN ORG
# productï¿½s PERSON
# US GPE
# countriesï¿½ ORG
# no more than 5 days DATE
# marketï¿½s GPE
# Oracle  SQL Server ORG
# HSQL GPE
# MS Access ORG
# 2 days DATE
# 100% PERCENT
# 100% PERCENT
# databaseï¿½s ORG
# 100% PERCENT
# 100% PERCENT
# 100% PERCENT
# SC ORG
# 90% PERCENT
# US GPE
# 90% PERCENT
# the J2SE/J2EE ORG
# Look and Feel WORK_OF_ART
# no more than 30min. PERCENT
# 6 CARDINAL
# System FAC
# third ORDINAL
# F:The System PRODUCT
# Inventory Quantity Adjustment ORG
# F:The System PRODUCT
# Inventory Quantity Adjustment ORG
# F: PRODUCT
# F: The System PRODUCT
# PFE ORG
# F: PRODUCT
# F:PME Subsystem PRODUCT
# F:PME Subsystem PRODUCT
# F:PME Subsystem PRODUCT
# more than one CARDINAL
# F:The RMS System PRODUCT
# Windows XP NORP
# GUI ORG
# F:The System PRODUCT
# Inventory Quantity Adjustment ORG
# daily DATE
# F:The System PRODUCT
# Inventory Quantity Adjustment ORG
# Administration ORG
# under 5 seconds TIME
# PIN ORG
# under 5 seconds TIME
# under 5 minutes TIME
# subscriberï¿½ PRODUCT
# under 10 minutes TIME
# under 5 seconds TIME
# 2 minutes TIME
# under 1 minute TIME
# under 5 minutes TIME
# under 5 minutes TIME
# under 2 minutes TIME
# under 2 minutes TIME
# Excel PRODUCT
# African NORP
# non-Africans NORP
# US GPE
# 90% PERCENT
# US GPE
# 4 CARDINAL
# US GPE
# 2 CARDINAL
# US GPE
# 70% PERCENT
# 2 weeks DATE
# US GPE
# 95% PERCENT
# a month DATE
# US GPE
# customerï¿½s ORG
# US GPE
# under 3 minutes TIME
# US GPE
# US GPE
# 5 seconds TIME
# 15 seconds TIME
# 10 seconds TIME
# Izogn NORP
# 24 hours TIME
# 365 days per year DATE
# 99.5% PERCENT
# SC ORG
# 50 CARDINAL
# SC ORG
# 700 CARDINAL
# SC ORG
# 1 000 CARDINAL
# SC ORG
# 100 000 CARDINAL
# MN ORG
# 2 years DATE
# 6.0 CARDINAL
# 7.x FAC
# Firefox 1.0 LAW
# the CyberSource API PRODUCT
# MSN ORG
# Windows Media Player 9.0 ORG
# 56k DATE
# 256k CARDINAL
# MN:Promotional ORG
# a day DATE
# 2 minutes TIME
# 2 minutes TIME
# 24 hour TIME
# US GPE
# M-F PRODUCT
# Izogn NORP
# 1 working day DATE
# 2 day DATE
# weekly DATE
# Privacy Policy ORG
# organizationï¿½s GPE
# Nigeria GPE
# Africans NORP
# Nigerians NORP
# Flash PERSON
# African NORP
# PHP ORG
# Windows Media Player ORG
# up to 2 days DATE
# Izogn NORP
# F:System PRODUCT
# $5  $ MONEY
# 10 MONEY
# 20 MONEY
# F: System PRODUCT
# Friday DATE
# 4 CARDINAL
# F:System PRODUCT
# ï¿½My Accountï¿½ PRODUCT
# F: Pre PRODUCT
# F: Movies PRODUCT
# 2-day DATE
# F: Daily PRODUCT
# F: PRODUCT
# 5 minutes TIME
# 90% PERCENT
# the business hours of 8AM TIME
# CST ORG
# 8PM CARDINAL
# CST ORG
# 3 minutes TIME
# 99% PERCENT
# longer than 25 seconds TIME
# 97% PERCENT
# longer than 25 seconds TIME
# the Auto Rep Assignment ORG
# 3 minutes TIME
# 24x7 CARDINAL
# MN ORG
# maintenance hours TIME
# F: PRODUCT
# Vendor ORG
# ARA ORG
# F:Prior PRODUCT
# 24 hours TIME
# seven days per week DATE
# 95% PERCENT
# no more than 4% PERCENT
# US GPE
# Nine CARDINAL
# ten CARDINAL
# US GPE
# English LANGUAGE
# Spanish LANGUAGE
# French LANGUAGE
# 95% PERCENT
# no more than 4% PERCENT
# F: Once PRODUCT
# 24 hours TIME
# F: Once PRODUCT
# F: Once PRODUCT
# F: Once PRODUCT
# 5 CARDINAL
# 5 CARDINAL
# first ORDINAL
# F: PRODUCT
# one CARDINAL
# one CARDINAL
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# F: PRODUCT
# US GPE
# 2 minutes TIME
# US GPE
# 10 minutes TIME
# the DePaul TeleServices Center ORG
# 90% PERCENT
# 56k CARDINAL
# no more than 6 seconds QUANTITY
# 90% PERCENT
# 112k CARDINAL
# 90% PERCENT
# every day of the year DATE
# 12:00AM ORG
# 11:59PM DATE
# MN ORG
# callerï¿½s NORP
# 90% PERCENT
# 80% PERCENT
# Monitoring Services ORG
# City of Chicago Application Development Guide Framework ORG
# Application Development Framework ORG
# Graphical User Interface WORK_OF_ART
# US GPE
# Monitoring Services ORG
# System Administrators ORG
# two weeks DATE
# US GPE
# Error Tracking Services ORG
# the System Administrators ORG
# 99% PERCENT
# US GPE
# System Administrators ORG
# Asynchronous Messaging WORK_OF_ART
# Load Balancing WORK_OF_ART
# 2 seconds TIME
# 2 seconds TIME
# every 1 second TIME
# Dynamic Change Support and Transparent resource WORK_OF_ART
# Transparent Resource ORG
# more than 1 day DATE
# 99% PERCENT
# 99.99% PERCENT
# SC ORG
# 1 million CARDINAL
# CSR ORG
# Datastream GPE
# CSR ORG
# EAM ORG
# two CARDINAL
# MN ORG
# MN ORG
# every six months DATE
# quarterly DATE
# every six months DATE
# MN ORG
# WS-Security ORG
# Integrity Checking PERSON
# one year DATE
# IBM ORG
# CCR ORG
# one CARDINAL
# IBM ORG
# one CARDINAL
# CCR ORG
# CCR ORG
# 800 CARDINAL
# 600 CARDINAL
# CCR ORG
# WCS ORG
# CCR ORG
# at least one CARDINAL
# US GPE
# 100% PERCENT
# US GPE
# 90% PERCENT
# first ORDINAL
# IBM ORG
# US GPE
# US GPE
# one CARDINAL
# 90% PERCENT
# US GPE
# CCR ORG
# WCS ORG
# One CARDINAL
# 100% PERCENT
# CCR ORG
# CCR ORG
# US GPE
# WCS ORG
# the Corporate Community Grants ORG
# CCR ORG
# WCS ORG
# W3 GPE
# WCS ORG
# 95% PERCENT
# W3 GPE
# SC ORG
# WCS ORG
# WCS ORG
# SC ORG
# WCS ORG
# the United States GPE
# the United States GPE
# CCR ORG
# WCS ORG
# Windows NORP
# WCS ORG
# IBM ORG
# Brio PERSON
# WCS ORG
# Microsoft ORG
# Excel PRODUCT
# Lotus 1-2-3 ORG
# Brio ORG
# .123 CARDINAL
# MN ORG
# WCS ORG
# WCS ORG
# CCR ORG
# WCS ORG
# Guides PERSON
# WCS ORG
# Corporate Community Grants ORG
# CCR ORG
# IBM ORG
# WCS ORG
# WCS ORG
# userï¿½s ORG
# ownerï¿½s GPE
# one CARDINAL
# 5 CARDINAL
# first ORDINAL
# 150 CARDINAL
# US GPE
# 30 seconds TIME
# US GPE
# ï¿½dropï¿½ ORG
# one CARDINAL
# ownerï¿½s GPE
# US GPE
# at least 25 CARDINAL
# NFL ORG
# US GPE
# one fourth CARDINAL
# second ORDINAL
# most 10 minutes TIME
# one CARDINAL
# Disputes PERSON
# 350 CARDINAL
# 24x7x365 CARDINAL
# Monday DATE
# 3:00am to 4:00am EST TIME
# Sunday 1:00amd DATE
# the Statement Database FAC
# the Disputes System ORG
# the Statement Database FAC
# 95% PERCENT
# US GPE
# US GPE
# US GPE
# US GPE
# no later 30 DATE
# CMA ORG
# CMA ORG
# no later 60 seconds TIME
# CMA ORG
# every hour TIME
# 24 hours TIME
# 365 days  per year DATE
# 1000 CARDINAL
# 999 CARDINAL
# CMA ORG
# SC ORG
# SC ORG
# 1000 CARDINAL
# SC ORG
# 1000 CARDINAL
# 5 CARDINAL
# the next year DATE
# US GPE
# PO ORG
# Windows CE LOC
# Palm ORG
# MLS ORG
# SC ORG
# SC ORG
# 10 CARDINAL
# 9am to 5pm TIME
# SC ORG
# 100% PERCENT
# the next 10 years DATE
# SC ORG
# 5 years DATE
# the Nursing Department ORG
# DePaul University ORG
# the Program Administrators/Nursing Staff Members ORG
# US GPE
# the Program Administrators/Nursing Staff Members ORG
# US GPE
# one day DATE
# US GPE
# US GPE
# 50% PERCENT
# the first year DATE
# US GPE
# the Program Administrators/Nursing Staff Members ORG
# 3 Program Administrators/Nursing Staff ORG
# US GPE
# US GPE
# Standard English PERSON
# the national Nursing Community ORG
# 5 seconds TIME
# 30 seconds TIME
# between the hours of 8am and 6pm TIME
# the Windows XP Professional ORG
# Program Administrators/Nursing Staff Members ORG
# Susan Poslusny PERSON
# Dr Julie Donalek PERSON
# CampusConnect ORG
# Susan Poslusny PERSON
# Karen Sysol PERSON
# CampusConnect ORG
# organizationï¿½s GPE
# organizationï¿½s GPE
# one CARDINAL
# F:Program Administrators ORG
# F:Program Administrators ORG
# F:Students PRODUCT
# the cohortï¿½s Program of Study ORG
# F:Program Administrators ORG
# F: PRODUCT
# Program Administrators ORG
# F: PRODUCT
# Program Administrators ORG
# F:Program Administrators ORG
# MN:Application ORG
# 3AM ORDINAL
# 6 AM TIME
# Wednesday DATE
# morning TIME
# NFL ORG
# season DATE
# MN ORG
# NFL ORG
# season DATE
# 1.0 CARDINAL
# 1.0 CARDINAL
# the Sync Matrix 1.0 LAW
# the Exercise Managment Tool ORG
# 1.0 CARDINAL
# Venues GPE
# RFS ORG
# 24/7 CARDINAL
# RFS ORG
# 90% PERCENT
# 98% PERCENT
# 2% PERCENT
# 1 hour TIME
# 400 CARDINAL
# Microsoft ORG
# 5.0 CARDINAL
# Microsoft ORG
# 1.1 CARDINAL
# Microsoft ORG
# RFS ORG
# BDW ORG
# BDW ORG
# RFS ORG
# 3 hours TIME
# every year DATE
# October month-end DATE
# up to 5 CARDINAL
# year DATE
# RFS ORG
# every year DATE
# one week DATE
# 2 weeks DATE
# PCG Finance ORG
# MN ORG
# BDW ORG
# RFS ORG
# 100% PERCENT
# October month-end DATE
# RFS ORG
# RFS ORG
# UAS ORG
# RFS ORG
# RFS ORG
# PCG ORG
# RFS ORG
# ENET Securities ORG
# 95% PERCENT
# Architecture ORG
# 5% PERCENT
# one month DATE
# 800x600 CARDINAL
# 95% PERCENT
# 5% PERCENT
# a week DATE
# US GPE
# a week DATE
# 98% PERCENT
# 2 CARDINAL
# 90% PERCENT
# 10% PERCENT
# more than 10 CARDINAL
# more than 10 seconds TIME
# a given quarter DATE
